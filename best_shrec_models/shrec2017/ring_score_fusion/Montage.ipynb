# %%
import os

# %%
pwd = '/home/minhb/Desktop/data/shrec17_render_square_att/'
pwd_save = '/home/minhb/Desktop/data/shrec17_render_square_att_montage'

# %%
for u in os.listdir(pwd):
    command =  'montage -mode concatenate -tile 8 $(ls {}/*) \
{}/{}.png'.format(pwd+u, pwd_save,u)
    os.system(command)
    print command
# Out:
# montage -mode concatenate -tile 8 $(ls /home/minhb/Desktop/data/shrec17_render_square_att/025_318840.ply/*) /home/minhb/Desktop/data/shrec17_render_square_att_montage/025_318840.ply.png
# montage -mode concatenate -tile 8 $(ls /home/minhb/Desktop/data/shrec17_render_square_att/080_333.ply/*) /home/minhb/Desktop/data/shrec17_render_square_att_montage/080_333.ply.png
# montage -mode concatenate -tile 8 $(ls /home/minhb/Desktop/data/shrec17_render_square_att/032_287.ply/*) /home/minhb/Desktop/data/shrec17_render_square_att_montage/032_287.ply.png
# montage -mode concatenate -tile 8 $(ls /home/minhb/Desktop/data/shrec17_render_square_att/611_986512.ply/*) /home/minhb/Desktop/data/shrec17_render_square_att_montage/611_986512.ply.png
# montage -mode concatenate -tile 8 $(ls /home/minhb/Desktop/data/shrec17_render_square_att/093_23645b.ply/*) /home/minhb/Desktop/data/shrec17_render_square_att_montage/093_23645b.ply.png
# ...

# %%
'montage -mode concatenate -tile 8 $(ls {}) \
{}/{}.png'.format(pwd+u, pwd_save,u)
# Out:
# 'montage -mode concatenate -tile 8 $(ls /home/minhb/Desktop/data/shrec17_render_square_att/065_1434200.ply) /home/minhb/Desktop/data/shrec17_render_square_att_montage/065_1434200.ply.png'
